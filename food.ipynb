# %%
import pandas as pd

df = pd.read_csv('/Users/jamesswank/Downloads/Grocery_S_ExportTable1.csv')

df
# Out:
#      OID_ Status  Score Match_type                    Match_addr  \
# 0       1      M  96.67          A   100 W LITTLETON BLVD, 80120
# 1       2      M  94.86          A        6000 S HOLLY ST, 80111
# 2       3      M  97.04          A     6100 S GUN CLUB RD, 80016
# 3       4      M  96.92          A       6412 S PARKER RD, 80016
# 4       5      M  75.63          A        14000 E EXPOSITION AVE
# ..    ...    ...    ...        ...                           ...
# 102   103      M  96.28          A     1355 N KRAMERIA ST, 80220
# 103   104      M  97.14          A      7150 LEETSDALE DR, 80224
# 104   105      M  96.92          A       9751 S PARKER RD, 80134
# 105   106      M  96.97          A  3333 S WADSWORTH BLVD, 80227
# 106   107      M  96.80          A        200 N QUEBEC ST, 80230
#
#                Store                                            Address  \
# 0        King Sooper     100 W Littleton Blvd, Littleton, CO  80120\r\n
# ...
